# %% [markdown]
# ## Cat/Dog Binary Classification

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense,Conv2D,MaxPooling2D,BatchNormalization

from tensorflow.keras.preprocessing.image import ImageDataGenerator


import numpy as np
from tensorflow.keras.preprocessing import image

# %%
## Initialising the CNN
classifier = Sequential()

# %%
classifier.add(Conv2D(64,(3,3),input_shape = (64,64,3), activation = 'relu'))
## MaxPooling
classifier.add(MaxPooling2D(pool_size = (2,2)))
classifier.add(BatchNormalization())
## Add another layer
classifier.add(Conv2D(64,(3,3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2,2)))
classifier.add(BatchNormalization())
## Add another layer
classifier.add(Conv2D(64,(3,3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2,2)))
classifier.add(BatchNormalization())

# %%
## Flattening
classifier.add(Flatten())

# %%
## Fully connected ANN, Hidden ANN and output layer
classifier.add(Dense(units = 128, activation = 'relu'))

# %%
#output layer
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %%
## Compliling
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 62, 62, 64)        1792
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 31, 31, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 29, 29, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 64)          256
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               295040
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 371,585
# Trainable params: 371,201
# Non-trainable params: 384
# _________________________________________________________________

# %%
## data importing  scaling

train_datagen = ImageDataGenerator(rescale=1./255)

# %%
## Scaling test data
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
## Importing training data
train_set = train_datagen.flow_from_directory('dataset/training',target_size=(64, 64),class_mode='binary')
# Out:
# Found 98 images belonging to 2 classes.

# %%
train_set.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %% [markdown]
# #which is cat which is dog?
# label_map = (train_set.class_indices)
# print(label_map)

# %%
## Importng test data
test_set = test_datagen.flow_from_directory('dataset/test',target_size=(64, 64),class_mode='binary')
# Out:
# Found 38 images belonging to 2 classes.

# %%
## fitting model to images
classifier.fit(train_set,epochs=50,validation_data=test_set)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 2s 290ms/step - loss: 1.0666 - accuracy: 0.4490 - val_loss: 0.6950 - val_accuracy: 0.5000
# Epoch 2/50
# 4/4 [==============================] - 1s 137ms/step - loss: 0.7105 - accuracy: 0.6122 - val_loss: 0.6902 - val_accuracy: 0.5000
# Epoch 3/50
# 4/4 [==============================] - 1s 186ms/step - loss: 0.5977 - accuracy: 0.6327 - val_loss: 0.6892 - val_accuracy: 0.5263
# Epoch 4/50
# 4/4 [==============================] - 1s 189ms/step - loss: 0.6040 - accuracy: 0.6837 - val_loss: 0.7037 - val_accuracy: 0.5000
# Epoch 5/50
# 4/4 [==============================] - 1s 187ms/step - loss: 0.5289 - accuracy: 0.6939 - val_loss: 0.6888 - val_accuracy: 0.4737
# Epoch 6/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.5478 - accuracy: 0.7143 - val_loss: 0.6876 - val_accuracy: 0.5000
# Epoch 7/50
# 4/4 [==============================] - 1s 186ms/step - loss: 0.6328 - accuracy: 0.6429 - val_loss: 0.6866 - val_accuracy: 0.5263
# Epoch 8/50
# 4/4 [==============================] - 1s 137ms/step - loss: 0.3394 - accuracy: 0.8980 - val_loss: 0.6893 - val_accuracy: 0.4737
# Epoch 9/50
# 4/4 [==============================] - 1s 133ms/step - loss: 0.4097 - accuracy: 0.7959 - val_loss: 0.6846 - val_accuracy: 0.6316
# Epoch 10/50
# 4/4 [==============================] - 1s 133ms/step - loss: 0.2878 - accuracy: 0.8980 - val_loss: 0.6825 - val_accuracy: 0.6316
# Epoch 11/50
# 4/4 [==============================] - 1s 206ms/step - loss: 0.2061 - accuracy: 0.9490 - val_loss: 0.6916 - val_accuracy: 0.4211
# Epoch 12/50
# 4/4 [==============================] - 1s 205ms/step - loss: 0.2902 - accuracy: 0.8776 - val_loss: 0.6893 - val_accuracy: 0.5263
# Epoch 13/50
# 4/4 [==============================] - 1s 167ms/step - loss: 0.2187 - accuracy: 0.8980 - val_loss: 0.7059 - val_accuracy: 0.5263
# Epoch 14/50
# 4/4 [==============================] - 1s 133ms/step - loss: 0.1982 - accuracy: 0.9286 - val_loss: 0.6785 - val_accuracy: 0.5526
# Epoch 15/50
# 4/4 [==============================] - 1s 185ms/step - loss: 0.1259 - accuracy: 0.9898 - val_loss: 0.6698 - val_accuracy: 0.5526
# Epoch 16/50
# 4/4 [==============================] - 1s 140ms/step - loss: 0.1103 - accuracy: 0.9796 - val_loss: 0.6858 - val_accuracy: 0.4737
# Epoch 17/50
# 4/4 [==============================] - 1s 222ms/step - loss: 0.1535 - accuracy: 0.9592 - val_loss: 0.6815 - val_accuracy: 0.5000
# Epoch 18/50
# 4/4 [==============================] - 1s 163ms/step - loss: 0.0685 - accuracy: 0.9898 - val_loss: 0.6790 - val_accuracy: 0.5526
# Epoch 19/50
# 4/4 [==============================] - 1s 172ms/step - loss: 0.0691 - accuracy: 0.9796 - val_loss: 0.6748 - val_accuracy: 0.5526
# Epoch 20/50
# 4/4 [==============================] - 1s 170ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.6627 - val_accuracy: 0.5526
# Epoch 21/50
# 4/4 [==============================] - 1s 177ms/step - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.6664 - val_accuracy: 0.5526
# Epoch 22/50
# 4/4 [==============================] - 1s 173ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.6806 - val_accuracy: 0.6053
# Epoch 23/50
# 4/4 [==============================] - 1s 173ms/step - loss: 0.0619 - accuracy: 0.9796 - val_loss: 0.6966 - val_accuracy: 0.5263
# Epoch 24/50
# 4/4 [==============================] - 1s 162ms/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 0.6897 - val_accuracy: 0.5526
# Epoch 25/50
# 4/4 [==============================] - 1s 171ms/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.6869 - val_accuracy: 0.4737
# Epoch 26/50
# 4/4 [==============================] - 1s 223ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.6873 - val_accuracy: 0.4737
# Epoch 27/50
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.6863 - val_accuracy: 0.5000
# Epoch 28/50
# 4/4 [==============================] - 1s 247ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.6873 - val_accuracy: 0.5263
# Epoch 29/50
# 4/4 [==============================] - 1s 245ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.6899 - val_accuracy: 0.5526
# Epoch 30/50
# 4/4 [==============================] - 1s 238ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.6897 - val_accuracy: 0.5526
# Epoch 31/50
# 4/4 [==============================] - 1s 190ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.6877 - val_accuracy: 0.5526
# Epoch 32/50
# 4/4 [==============================] - 1s 180ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.6859 - val_accuracy: 0.5526
# Epoch 33/50
# 4/4 [==============================] - 1s 163ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.6862 - val_accuracy: 0.5526
# Epoch 34/50
# 4/4 [==============================] - 1s 162ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.6867 - val_accuracy: 0.5263
# Epoch 35/50
# 4/4 [==============================] - 1s 160ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.6895 - val_accuracy: 0.5526
# Epoch 36/50
# 4/4 [==============================] - 1s 237ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6958 - val_accuracy: 0.5526
# Epoch 37/50
# 4/4 [==============================] - 1s 191ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6993 - val_accuracy: 0.5526
# Epoch 38/50
# 4/4 [==============================] - 1s 190ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.6979 - val_accuracy: 0.5526
# Epoch 39/50
# 4/4 [==============================] - 1s 182ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6950 - val_accuracy: 0.5789
# Epoch 40/50
# 4/4 [==============================] - 1s 192ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.6946 - val_accuracy: 0.5526
# Epoch 41/50
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6959 - val_accuracy: 0.5526
# Epoch 42/50
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.6987 - val_accuracy: 0.5526
# Epoch 43/50
# 4/4 [==============================] - 1s 177ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.7013 - val_accuracy: 0.5526
# Epoch 44/50
# 4/4 [==============================] - 1s 170ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.7053 - val_accuracy: 0.5526
# Epoch 45/50
# 4/4 [==============================] - 1s 190ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.7094 - val_accuracy: 0.5526
# Epoch 46/50
# 4/4 [==============================] - 1s 183ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.7133 - val_accuracy: 0.5526
# Epoch 47/50
# 4/4 [==============================] - 1s 166ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7180 - val_accuracy: 0.5526
# Epoch 48/50
# 4/4 [==============================] - 1s 173ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.7223 - val_accuracy: 0.5526
# Epoch 49/50
# 4/4 [==============================] - 1s 223ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7290 - val_accuracy: 0.5526
# Epoch 50/50
# 4/4 [==============================] - 1s 183ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.7363 - val_accuracy: 0.5789

# %%
#save the model
classifier.save('catdogmodel1311.h5')

# %%
## prediction of single new data

test_image= image.load_img('dataset/inference/dog1.jpg' ,target_size =(64,64))

# %%
test_image
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1CDA1F25B08>

# %%
## Convert image to array
test_image = image.img_to_array(test_image)

# %%
## For single prediction change the dimension . 

test_image=test_image.reshape(1,64,64,3)

# %%
result = classifier.predict(test_image)

# %%
result
# Out:
# array([[1.]], dtype=float32)

# %%
result=np.around(result)

# %%
## Class label of dog and cat

if result == 1:
    prediction = 'dog'
else:
   prediction = 'cat'

# %%
prediction
# Out:
# 'dog'
